# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
cnt = pd.read_csv ("countries.csv")
cnt.sample(10)
# Out:
#                location  population  population_density  median_age  \
# 70               Guyana      786559               3.952        26.3
# 97        Liechtenstein       38137             237.012         NaN
# 52    Equatorial Guinea     1402985              45.194        22.4
# 157         South Korea    51269183             527.967        43.4
# 36             Colombia    50882884              44.223        32.2
# 38                Congo     5518092              15.405        19.0
# 48   Dominican Republic    10847904             222.873        27.6
# 78                 Iran    83992953              49.831        32.4
# 64                Ghana    31072945             126.719        21.1
# 164         Switzerland     8654618             214.243        43.1
#
#      aged_65_older  aged_70_older  gdp_per_capita  extreme_poverty  \
# 70           5.305          2.837        7435.047              NaN
# 97             NaN            NaN             NaN              NaN
# 52           2.846          1.752       22604.873              NaN
# 157         13.914          8.622       35938.374              0.2
# 36           7.646          4.312       13254.949              4.5
# 38           3.402          2.063        4881.406             37.0
# 48           6.981          4.419       14600.861              1.6
# 78           5.440          3.182       19082.620              0.2
# 64           3.385          1.948        4227.630             12.0
# 164         18.436         12.644       57410.166              NaN
#
#      life_expectancy  human_development_index
# 70             69.91                    0.654
# 97             82.49                    0.916
# 52             58.74                    0.591
# 157            83.03                    0.903
# 36             77.29                    0.747
# 38             64.57                    0.606
# 48             74.08                    0.736
# 78             76.68                    0.798
# 64             64.07                    0.592
# 164            83.78                    0.944

# %%
cnt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   location                 190 non-null    object
#  1   population               190 non-null    int64
#  2   population_density       186 non-null    float64
#  3   median_age               181 non-null    float64
#  4   aged_65_older            179 non-null    float64
#  5   aged_70_older            180 non-null    float64
#  6   gdp_per_capita           182 non-null    float64
#  7   extreme_poverty          124 non-null    float64
#  8   life_expectancy          189 non-null    float64
#  9   human_development_index  183 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 15.0+ KB

# %%
happy_score_cnt = pd.read_csv('happiness_scores.csv')

# %%
happy_score_cnt.head()
# Out:
#       location  happiness_score
# 0      Finland            7.809
# 1      Denmark            7.646
# 2  Switzerland            7.560
# 3      Iceland            7.504
# 4       Norway            7.488

# %%
cnt = pd.merge(cnt, happy_score_cnt, on = "location", how = "left")
cnt.head()
# Out:
#       location  population  population_density  median_age  aged_65_older  \
# 0  Afghanistan    38928341              54.422        18.6          2.581
# 1      Albania     2877800             104.871        38.0         13.188
# 2      Algeria    43851043              17.348        29.1          6.211
# 3      Andorra       77265             163.755         NaN            NaN
# 4       Angola    32866268              23.890        16.8          2.405
#
#    aged_70_older  gdp_per_capita  extreme_poverty  life_expectancy  \
# 0          1.337        1803.987              NaN            64.83
# 1          8.643       11803.431              1.1            78.57
# 2          3.857       13913.839              0.5            76.88
# 3            NaN             NaN              NaN            83.73
# 4          1.362        5819.495              NaN            61.15
#
#    human_development_index  happiness_score
# 0                    0.498            2.567
# 1                    0.785            4.883
# 2                    0.754            5.005
# 3                    0.858              NaN
# 4                    0.581              NaN

# %% [markdown]
# # EDA

# %%
cnt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 0 to 189
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   location                 190 non-null    object
#  1   population               190 non-null    int64
#  2   population_density       186 non-null    float64
#  3   median_age               181 non-null    float64
#  4   aged_65_older            179 non-null    float64
#  5   aged_70_older            180 non-null    float64
#  6   gdp_per_capita           182 non-null    float64
#  7   extreme_poverty          124 non-null    float64
#  8   life_expectancy          189 non-null    float64
#  9   human_development_index  183 non-null    float64
#  10  happiness_score          149 non-null    float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 17.8+ KB

# %%
cnt.describe()
# Out:
#          population  population_density  median_age  aged_65_older  \
# count  1.900000e+02          186.000000  181.000000     179.000000
# mean   8.183077e+07          341.658210   30.204972       8.590022
# std    5.819950e+08         1612.572496    9.171031       6.198639
# min    8.090000e+02            1.980000   15.100000       1.144000
# 25%    2.367885e+06           35.972500   21.700000       3.421500
# 50%    9.493482e+06           82.464000   29.400000       6.211000
# 75%    3.076120e+07          208.157000   38.700000      14.053000
# max    7.794799e+09        19347.500000   48.200000      27.049000
#
#        aged_70_older  gdp_per_capita  extreme_poverty  life_expectancy  \
# count     180.000000      182.000000       124.000000       189.000000
# mean        5.436161    18439.706637        13.916129        72.862011
# std         4.225454    19589.091950        20.311975         7.584835
# min         0.526000      661.240000         0.100000        53.280000
# 25%         2.033500     3924.303000         0.600000        67.270000
# 50%         3.541500    11822.138500         2.350000        74.250000
# 75%         8.651750    26069.050500        21.675000        77.970000
# max        18.493000   116935.600000        77.600000        86.750000
#
#        human_development_index  happiness_score
# count               183.000000       149.000000
# mean                  0.708869         5.472221
# std                   0.154410         1.125246
# min                   0.354000         2.567000
# 25%                   0.588500         4.677000
# 50%                   0.736000         5.515000
# 75%                   0.823000         6.258000
# max                   0.953000         7.809000

# %%
cnt[(cnt["population"] < 1000) | (cnt["population"] > 1000000000) | (cnt["population_density"] > 15000)]
# Out:
#     location  population  population_density  median_age  aged_65_older  \
# 35     China  1439323774             147.674        38.7         10.641
# 76     India  1380004385             450.419        28.2          5.989
# 111   Monaco       39244           19347.500         NaN            NaN
# 183  Vatican         809                 NaN         NaN            NaN
# 186    World  7794798729              58.045        30.9          8.696
#
#      aged_70_older  gdp_per_capita  extreme_poverty  life_expectancy  \
# 35           5.929       15308.712              0.7            76.91
# 76           3.414        6426.674             21.2            69.66
# 111            NaN             NaN              NaN            86.75
# 183            NaN             NaN              NaN            75.12
# 186          5.355       15469.207             10.0            72.58
#
#      human_development_index  happiness_score
# 35                     0.752            5.124
# 76                     0.640            3.573
# 111                      NaN              NaN
# 183                      NaN              NaN
# 186                      NaN              NaN

# %%
cnt[(cnt["gdp_per_capita"] < 1000) | (cnt["extreme_poverty"] > 70)]
# Out:
#                          location  population  population_density  median_age  \
# 27                        Burundi    11890781             423.062        17.5
# 32       Central African Republic     4829764               7.479        18.3
# 44   Democratic Republic of Congo    89561404              35.879        17.0
# 95                        Liberia     5057677              49.127        19.2
# 100                    Madagascar    27691019              43.951        19.6
# 101                        Malawi    19129955             197.519        18.1
# 122                         Niger    24206636              16.955        15.1
#
#      aged_65_older  aged_70_older  gdp_per_capita  extreme_poverty  \
# 27           2.562          1.504         702.225             71.7
# 32           3.655          2.251         661.240              NaN
# 44           3.020          1.745         808.133             77.1
# 95           3.057          1.756         752.788             38.6
# 100          2.929          1.686        1416.440             77.6
# 101          2.979          1.783        1095.042             71.4
# 122          2.553          1.378         926.000             44.5
#
#      life_expectancy  human_development_index  happiness_score
# 27             61.58                    0.417            3.775
# 32             53.28                    0.367            3.476
# 44             60.68                    0.457            5.194
# 95             64.10                    0.435            4.558
# 100            67.04                    0.519            4.166
# 101            64.26                    0.477            3.538
# 122            62.42                    0.354            4.910

# %%
cnt.set_index("location", inplace = True)

# %%
cnt.head()
# Out:
#              population  population_density  median_age  aged_65_older  \
# location
# Afghanistan    38928341              54.422        18.6          2.581
# Albania         2877800             104.871        38.0         13.188
# Algeria        43851043              17.348        29.1          6.211
# Andorra           77265             163.755         NaN            NaN
# Angola         32866268              23.890        16.8          2.405
#
#              aged_70_older  gdp_per_capita  extreme_poverty  life_expectancy  \
# location
# Afghanistan          1.337        1803.987              NaN            64.83
# Albania              8.643       11803.431              1.1            78.57
# Algeria              3.857       13913.839              0.5            76.88
# Andorra                NaN             NaN              NaN            83.73
# Angola               1.362        5819.495              NaN            61.15
#
#              human_development_index  happiness_score
# location
# Afghanistan                    0.498            2.567
# Albania                        0.785            4.883
# Algeria                        0.754            5.005
# Andorra                        0.858              NaN
# Angola                         0.581              NaN

# %%
sns.pairplot(cnt)

# %%
cnt_new = cnt[["median_age", "aged_65_older", "gdp_per_capita", "extreme_poverty", "life_expectancy", "human_development_index", "happiness_score"]]
cnt_new.sample(10)
# Out:
#                       median_age  aged_65_older  gdp_per_capita  \
# location
# Malta                       42.4         19.426       36513.323
# United Arab Emirates        34.0          1.144       67293.483
# Tanzania                    17.7          3.108        2683.304
# Moldova                     37.6         10.864        5189.972
# Uganda                      16.4          2.168        1697.707
# Barbados                    39.8         14.952       16978.068
# Uruguay                     35.6         14.655       20551.409
# Kyrgyzstan                  26.3          4.489        3393.474
# Bhutan                      28.6          4.885        8708.597
# Peru                        29.1          7.151       12236.706
#
#                       extreme_poverty  life_expectancy  \
# location
# Malta                             0.2            82.53
# United Arab Emirates              NaN            77.97
# Tanzania                         49.1            65.46
# Moldova                           0.2            71.90
# Uganda                           41.6            63.37
# Barbados                          NaN            79.19
# Uruguay                           0.1            77.91
# Kyrgyzstan                        1.4            71.45
# Bhutan                            1.5            71.78
# Peru                              3.5            76.74
#
#                       human_development_index  happiness_score
# location
# Malta                                   0.878            6.773
# United Arab Emirates                    0.863            6.791
# Tanzania                                0.538            3.476
# Moldova                                 0.700            5.608
# Uganda                                  0.516            4.432
# Barbados                                0.800              NaN
# Uruguay                                 0.804            6.440
# Kyrgyzstan                              0.672            5.542
# Bhutan                                  0.612              NaN
# Peru                                    0.750            5.797

# %%
cnt_new.isnull().sum()
# Out:
# median_age                  9
# aged_65_older              11
# gdp_per_capita              8
# extreme_poverty            66
# life_expectancy             1
# human_development_index     7
# happiness_score            41
# dtype: int64

# %%
cnt_new.loc["World"]
# Out:
# median_age                    30.900
# aged_65_older                  8.696
# gdp_per_capita             15469.207
# extreme_poverty               10.000
# life_expectancy               72.580
# human_development_index          NaN
# happiness_score                  NaN
# Name: World, dtype: float64

# %%
for col in ["median_age", "aged_65_older", "life_expectancy"]:
    cnt_new[col].fillna(cnt_new[col]['World'], inplace=True)

cnt_new.isnull().sum()
# Out:
# median_age                  0
# aged_65_older               0
# gdp_per_capita              8
# extreme_poverty            66
# life_expectancy             0
# human_development_index     7
# happiness_score            41
# dtype: int64

# %%
cnt_new['human_development_index'].fillna(cnt_new['human_development_index'].mean(), inplace=True)

cnt_new.isnull().sum()
# Out:
# median_age                  0
# aged_65_older               0
# gdp_per_capita              8
# extreme_poverty            66
# life_expectancy             0
# human_development_index     0
# happiness_score            41
# dtype: int64

# %%
cnt_new[cnt_new["extreme_poverty"].isnull()].sample(20)
# Out:
#                                   median_age  aged_65_older  gdp_per_capita  \
# location
# Eritrea                                 19.3          3.607        1510.459
# Philippines                             25.2          4.803        7599.188
# Belarus                                 40.3         14.799       17167.967
# Suriname                                29.6          6.933       13767.119
# Liechtenstein                           30.9          8.696             NaN
# Angola                                  16.8          2.405        5819.495
# Equatorial Guinea                       22.4          2.846       22604.873
# Netherlands                             43.2         18.779       48472.545
# Saudi Arabia                            31.9          3.295       49045.411
# Japan                                   48.2         27.049       39002.223
# Bahrain                                 32.4          2.372       43290.705
# Saint Vincent and the Grenadines        31.8          7.724       10727.146
# Sudan                                   19.7          3.548        4466.507
# Cuba                                    43.1         14.738             NaN
# Belize                                  25.0          3.853        7824.362
# Kuwait                                  33.7          2.345       65530.537
# Taiwan                                  42.2          8.696             NaN
# Grenada                                 29.4          7.304       13593.877
# Afghanistan                             18.6          2.581        1803.987
# Serbia                                  41.2         17.366       14048.881
#
#                                   extreme_poverty  life_expectancy  \
# location
# Eritrea                                       NaN            66.32
# Philippines                                   NaN            71.23
# Belarus                                       NaN            74.79
# Suriname                                      NaN            71.68
# Liechtenstein                                 NaN            82.49
# Angola                                        NaN            61.15
# Equatorial Guinea                             NaN            58.74
# Netherlands                                   NaN            82.28
# Saudi Arabia                                  NaN            75.13
# Japan                                         NaN            84.63
# Bahrain                                       NaN            77.29
# Saint Vincent and the Grenadines              NaN            72.53
# Sudan                                         NaN            65.31
# Cuba                                          NaN            78.80
# Belize                                        NaN            74.62
# Kuwait                                        NaN            75.49
# Taiwan                                        NaN            80.46
# Grenada                                       NaN            72.40
# Afghanistan                                   NaN            64.83
# Serbia                                        NaN            76.00
#
#                                   human_development_index  happiness_score
# location
# Eritrea                                          0.440000              NaN
# Philippines                                      0.699000            6.006
# Belarus                                          0.808000            5.540
# Suriname                                         0.720000              NaN
# Liechtenstein                                    0.916000              NaN
# Angola                                           0.581000              NaN
# Equatorial Guinea                                0.591000              NaN
# Netherlands                                      0.931000            7.449
# Saudi Arabia                                     0.853000            6.406
# Japan                                            0.909000            5.871
# Bahrain                                          0.846000            6.227
# Saint Vincent and the Grenadines                 0.723000              NaN
# Sudan                                            0.502000              NaN
# Cuba                                             0.777000              NaN
# Belize                                           0.708000              NaN
# Kuwait                                           0.803000            6.102
# Taiwan                                           0.708869            6.455
# Grenada                                          0.772000              NaN
# Afghanistan                                      0.498000            2.567
# Serbia                                           0.787000            5.778

# %%
cnt_new.corr()["extreme_poverty"].sort_values(ascending = False)
# Out:
# extreme_poverty            1.000000
# gdp_per_capita            -0.507473
# aged_65_older             -0.573485
# happiness_score           -0.600319
# median_age                -0.697723
# life_expectancy           -0.751798
# human_development_index   -0.769612
# Name: extreme_poverty, dtype: float64

# %%
cnt_new.corr()["gdp_per_capita"].sort_values(ascending = False)
# Out:
# gdp_per_capita             1.000000
# human_development_index    0.750823
# happiness_score            0.727942
# life_expectancy            0.673646
# median_age                 0.639722
# aged_65_older              0.500403
# extreme_poverty           -0.507473
# Name: gdp_per_capita, dtype: float64

# %%
cnt_new.corr()["happiness_score"].sort_values(ascending = False)
# Out:
# happiness_score            1.000000
# human_development_index    0.787390
# life_expectancy            0.761917
# gdp_per_capita             0.727942
# median_age                 0.688966
# aged_65_older              0.641272
# extreme_poverty           -0.600319
# Name: happiness_score, dtype: float64

# %%
from sklearn.cluster import KMeans

# %%
cnt_hdi = cnt_new["human_development_index"].values.reshape(-1, 1)

# %%
kmeans_model = KMeans(n_clusters=4).fit(cnt_hdi)

# %%
cnt_hdi_pred = kmeans_model.predict(cnt_hdi)

print(cnt_hdi_pred)
# Out:
# [2 3 3 1 0 3 1 3 1 1 3 3 1 0 3 3 1 3 2 0 3 3 3 3 1 3 2 2 0 0 1 0 2 2 1 3 3
#  2 0 3 2 1 3 1 2 1 2 3 3 3 3 0 0 2 1 0 2 3 1 1 3 2 3 1 0 1 3 0 2 2 0 2 0 1
#  1 1 0 3 3 3 1 1 1 3 1 3 3 0 3 3 0 0 1 3 2 2 3 1 1 1 2 2 3 3 2 1 3 2 3 3 3
#  3 3 3 0 2 0 0 0 1 1 0 2 2 3 1 3 0 3 3 0 3 3 3 1 1 1 3 3 2 3 3 3 3 3 0 1 2
#  3 3 2 1 1 1 0 3 3 1 2 1 3 2 3 1 1 2 3 0 2 3 0 2 3 3 3 2 3 1 1 1 3 3 0 3 3
#  3 3 2 0 2]

# %%
np.unique(cnt_hdi_pred, return_counts=True)
# Out:
# (array([0, 1, 2, 3]), array([31, 46, 36, 77], dtype=int64))

# %%
cnt_new["hdi_clusters"] = cnt_hdi_pred
cnt_new.head(10)
# Out:
#                      median_age  aged_65_older  gdp_per_capita  \
# location
# Afghanistan                18.6          2.581        1803.987
# Albania                    38.0         13.188       11803.431
# Algeria                    29.1          6.211       13913.839
# Andorra                    30.9          8.696             NaN
# Angola                     16.8          2.405        5819.495
# Antigua and Barbuda        32.1          6.933       21490.943
# Argentina                  31.9         11.198       18933.907
# Armenia                    35.7         11.232        8787.580
# Australia                  37.9         15.504       44648.710
# Austria                    44.4         19.202       45436.686
#
#                      extreme_poverty  life_expectancy  \
# location
# Afghanistan                      NaN            64.83
# Albania                          1.1            78.57
# Algeria                          0.5            76.88
# Andorra                          NaN            83.73
# Angola                           NaN            61.15
# Antigua and Barbuda              NaN            77.02
# Argentina                        0.6            76.67
# Armenia                          1.8            75.09
# Australia                        0.5            83.44
# Austria                          0.7            81.54
#
#                      human_development_index  happiness_score  hdi_clusters
# location
# Afghanistan                            0.498            2.567             2
# Albania                                0.785            4.883             3
# Algeria                                0.754            5.005             3
# Andorra                                0.858              NaN             1
# Angola                                 0.581              NaN             0
# Antigua and Barbuda                    0.780              NaN             3
# Argentina                              0.825            5.975             1
# Armenia                                0.755            4.677             3
# Australia                              0.939            7.223             1
# Austria                                0.908            7.294             1

# %%
hdi_avg_hs = cnt_new.groupby("hdi_clusters")["happiness_score"].mean()
hdi_avg_hs
# Out:
# hdi_clusters
# 0    5.051238
# 1    6.659643
# 2    4.151667
# 3    5.446964
# Name: happiness_score, dtype: float64

# %%
cnt_new["happiness_score"] = cnt_new.groupby("hdi_clusters")["happiness_score"].apply(lambda x: x.fillna(x.mean()))

cnt_new.head(10)
# Out:
#                      median_age  aged_65_older  gdp_per_capita  \
# location
# Afghanistan                18.6          2.581        1803.987
# Albania                    38.0         13.188       11803.431
# Algeria                    29.1          6.211       13913.839
# Andorra                    30.9          8.696             NaN
# Angola                     16.8          2.405        5819.495
# Antigua and Barbuda        32.1          6.933       21490.943
# Argentina                  31.9         11.198       18933.907
# Armenia                    35.7         11.232        8787.580
# Australia                  37.9         15.504       44648.710
# Austria                    44.4         19.202       45436.686
#
#                      extreme_poverty  life_expectancy  \
# location
# Afghanistan                      NaN            64.83
# Albania                          1.1            78.57
# Algeria                          0.5            76.88
# Andorra                          NaN            83.73
# Angola                           NaN            61.15
# Antigua and Barbuda              NaN            77.02
# Argentina                        0.6            76.67
# Armenia                          1.8            75.09
# Australia                        0.5            83.44
# Austria                          0.7            81.54
#
#                      human_development_index  happiness_score  hdi_clusters
# location
# Afghanistan                            0.498         2.567000             2
# Albania                                0.785         4.883000             3
# Algeria                                0.754         5.005000             3
# Andorra                                0.858         6.659643             1
# Angola                                 0.581         5.051238             0
# Antigua and Barbuda                    0.780         5.446964             3
# Argentina                              0.825         5.975000             1
# Armenia                                0.755         4.677000             3
# Australia                              0.939         7.223000             1
# Austria                                0.908         7.294000             1

# %%
cnt_new.isnull().sum()
# Out:
# median_age                  0
# aged_65_older               0
# gdp_per_capita              8
# extreme_poverty            66
# life_expectancy             0
# human_development_index     0
# happiness_score             0
# hdi_clusters                0
# dtype: int64

# %%
cnt_new["gdp_per_capita"] = cnt_new.groupby("hdi_clusters")["gdp_per_capita"].apply(lambda x: x.fillna(x.mean()))
cnt_new["gdp_per_capita"] = cnt_new["gdp_per_capita"].fillna(cnt_new["gdp_per_capita"].mean())

cnt_new.head(10)
# Out:
#                      median_age  aged_65_older  gdp_per_capita  \
# location
# Afghanistan                18.6          2.581       1803.9870
# Albania                    38.0         13.188      11803.4310
# Algeria                    29.1          6.211      13913.8390
# Andorra                    30.9          8.696      44472.9145
# Angola                     16.8          2.405       5819.4950
# Antigua and Barbuda        32.1          6.933      21490.9430
# Argentina                  31.9         11.198      18933.9070
# Armenia                    35.7         11.232       8787.5800
# Australia                  37.9         15.504      44648.7100
# Austria                    44.4         19.202      45436.6860
#
#                      extreme_poverty  life_expectancy  \
# location
# Afghanistan                      NaN            64.83
# Albania                          1.1            78.57
# Algeria                          0.5            76.88
# Andorra                          NaN            83.73
# Angola                           NaN            61.15
# Antigua and Barbuda              NaN            77.02
# Argentina                        0.6            76.67
# Armenia                          1.8            75.09
# Australia                        0.5            83.44
# Austria                          0.7            81.54
#
#                      human_development_index  happiness_score  hdi_clusters
# location
# Afghanistan                            0.498         2.567000             2
# Albania                                0.785         4.883000             3
# Algeria                                0.754         5.005000             3
# Andorra                                0.858         6.659643             1
# Angola                                 0.581         5.051238             0
# Antigua and Barbuda                    0.780         5.446964             3
# Argentina                              0.825         5.975000             1
# Armenia                                0.755         4.677000             3
# Australia                              0.939         7.223000             1
# Austria                                0.908         7.294000             1

# %%
hdi_avg_pvrty = cnt_new.groupby("hdi_clusters")["extreme_poverty"].mean()        
hdi_avg_pvrty
# Out:
# hdi_clusters
# 0    16.845833
# 1     0.607407
# 2    42.817857
# 3     2.355556
# Name: extreme_poverty, dtype: float64

# %%
cnt_new["extreme_poverty"] = cnt_new.groupby("hdi_clusters")["extreme_poverty"].apply(lambda x: x.fillna(x.mean()))
cnt_new["extreme_poverty"] = cnt_new["extreme_poverty"].fillna(cnt_new["extreme_poverty"].mean())

cnt_new.head(10)
# Out:
#                      median_age  aged_65_older  gdp_per_capita  \
# location
# Afghanistan                18.6          2.581       1803.9870
# Albania                    38.0         13.188      11803.4310
# Algeria                    29.1          6.211      13913.8390
# Andorra                    30.9          8.696      44472.9145
# Angola                     16.8          2.405       5819.4950
# Antigua and Barbuda        32.1          6.933      21490.9430
# Argentina                  31.9         11.198      18933.9070
# Armenia                    35.7         11.232       8787.5800
# Australia                  37.9         15.504      44648.7100
# Austria                    44.4         19.202      45436.6860
#
#                      extreme_poverty  life_expectancy  \
# location
# Afghanistan                42.817857            64.83
# Albania                     1.100000            78.57
# Algeria                     0.500000            76.88
# Andorra                     0.607407            83.73
# Angola                     16.845833            61.15
# Antigua and Barbuda         2.355556            77.02
# Argentina                   0.600000            76.67
# Armenia                     1.800000            75.09
# Australia                   0.500000            83.44
# Austria                     0.700000            81.54
#
#                      human_development_index  happiness_score  hdi_clusters
# location
# Afghanistan                            0.498         2.567000             2
# Albania                                0.785         4.883000             3
# Algeria                                0.754         5.005000             3
# Andorra                                0.858         6.659643             1
# Angola                                 0.581         5.051238             0
# Antigua and Barbuda                    0.780         5.446964             3
# Argentina                              0.825         5.975000             1
# Armenia                                0.755         4.677000             3
# Australia                              0.939         7.223000             1
# Austria                                0.908         7.294000             1

# %%
cnt_new.isnull().sum()
# Out:
# median_age                 0
# aged_65_older              0
# gdp_per_capita             0
# extreme_poverty            0
# life_expectancy            0
# human_development_index    0
# happiness_score            0
# hdi_clusters               0
# dtype: int64

# %%
cnt_new1 = cnt_new.drop("hdi_clusters", axis=1)
cnt_new1.sample(10)
# Out:
#                                   median_age  aged_65_older  gdp_per_capita  \
# location
# India                                   28.2          5.989        6426.674
# Haiti                                   24.3          4.800        1653.173
# South Sudan                             19.2          3.441        1569.888
# South Korea                             43.4         13.914       35938.374
# Paraguay                                26.5          6.378        8827.010
# Serbia                                  41.2         17.366       14048.881
# Saint Vincent and the Grenadines        31.8          7.724       10727.146
# San Marino                              30.9          8.696       56861.470
# Guinea                                  19.0          3.135        1998.926
# Kenya                                   20.0          2.686        2993.028
#
#                                   extreme_poverty  life_expectancy  \
# location
# India                                   21.200000            69.66
# Haiti                                   23.500000            64.00
# South Sudan                             42.817857            57.85
# South Korea                              0.200000            83.03
# Paraguay                                 1.700000            74.25
# Serbia                                   2.355556            76.00
# Saint Vincent and the Grenadines         2.355556            72.53
# San Marino                               2.355556            84.97
# Guinea                                  35.300000            61.60
# Kenya                                   36.800000            66.70
#
#                                   human_development_index  happiness_score
# location
# India                                            0.640000         3.573000
# Haiti                                            0.498000         3.721000
# South Sudan                                      0.388000         2.817000
# South Korea                                      0.903000         5.872000
# Paraguay                                         0.702000         5.692000
# Serbia                                           0.787000         5.778000
# Saint Vincent and the Grenadines                 0.723000         5.446964
# San Marino                                       0.708869         5.446964
# Guinea                                           0.459000         4.949000
# Kenya                                            0.590000         4.583000

# %%
from pyclustertend import hopkins
from sklearn.preprocessing import scale

# %%
hopkins(cnt_new1, cnt_new1.shape[0])
# Out:
# 0.1727096926216637

# %%
hopkins(scale(cnt_new1), cnt_new1.shape[0])
# Out:
# 0.14708539316012345

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

scaler.fit(cnt_new1)
# Out:
# StandardScaler()

# %%
cnt_new1_scaled = scaler.transform(cnt_new1)

# %%
kmeans_model = KMeans(n_clusters=4, random_state=18).fit(cnt_new1_scaled)

# %%
cnt_new1_scaled_pred = kmeans_model.predict(cnt_new1_scaled)

print(cnt_new1_scaled_pred)
# Out:
# [2 1 1 0 3 1 1 1 0 0 1 1 1 3 1 1 0 3 2 3 3 1 3 1 0 0 2 2 3 3 0 3 2 2 1 1 1
#  3 2 1 2 0 1 0 2 0 3 1 1 1 3 1 3 2 0 3 2 3 0 0 3 3 1 0 3 0 1 3 2 2 3 2 3 0
#  0 0 3 3 1 3 0 0 0 1 0 3 1 2 1 1 3 3 0 1 2 2 1 0 0 0 2 2 1 1 2 0 1 3 1 1 1
#  1 3 1 1 2 3 3 3 0 0 1 2 2 1 0 1 3 3 1 3 1 1 3 0 0 0 0 1 2 1 1 1 3 1 3 1 2
#  1 1 2 0 0 0 3 3 3 0 2 0 1 2 1 0 0 2 1 3 2 1 3 2 1 1 1 2 1 0 0 0 1 1 3 1 1
#  1 1 2 2 2]

# %%
np.unique(cnt_new1_scaled_pred, return_counts=True)
# Out:
# (array([0, 1, 2, 3]), array([44, 67, 35, 44], dtype=int64))

# %%
from sklearn.metrics import silhouette_score
silhouette_score(cnt_new1_scaled, cnt_new1_scaled_pred)
# Out:
# 0.3210559038794048

# %%
cnt_new1['Kmeans_clusters'] = cnt_new1_scaled_pred

cnt_new1.sample(15)
# Out:
#                   median_age  aged_65_older  gdp_per_capita  extreme_poverty  \
# location
# Netherlands             43.2         18.779    48472.545000         0.607407
# Kuwait                  33.7          2.345    65530.537000         2.355556
# Algeria                 29.1          6.211    13913.839000         0.500000
# Lithuania               43.5         19.002    29524.265000         0.700000
# Monaco                  30.9          8.696    16037.449722         2.355556
# Slovenia                44.5         19.062    31400.840000         0.607407
# Mozambique              17.7          3.158     1136.103000        62.900000
# Vatican                 30.9          8.696    16037.449722         2.355556
# Paraguay                26.5          6.378     8827.010000         1.700000
# Chad                    16.7          2.486     1768.153000        38.400000
# Austria                 44.4         19.202    45436.686000         0.700000
# Namibia                 22.0          3.552     9541.808000        13.400000
# Sweden                  41.0         19.985    46949.283000         0.500000
# Laos                    24.4          4.029     6397.360000        22.700000
# Papua New Guinea        22.6          3.808     3823.194000        16.845833
#
#                   life_expectancy  human_development_index  happiness_score  \
# location
# Netherlands                 82.28                 0.931000         7.449000
# Kuwait                      75.49                 0.803000         6.102000
# Algeria                     76.88                 0.754000         5.005000
# Lithuania                   75.93                 0.858000         6.215000
# Monaco                      86.75                 0.708869         5.446964
# Slovenia                    81.32                 0.896000         6.363000
# Mozambique                  60.85                 0.437000         4.624000
# Vatican                     75.12                 0.708869         5.446964
# Paraguay                    74.25                 0.702000         5.692000
# Chad                        54.24                 0.404000         4.423000
# Austria                     81.54                 0.908000         7.294000
# Namibia                     63.71                 0.647000         4.571000
# Sweden                      82.80                 0.933000         7.353000
# Laos                        67.92                 0.601000         4.889000
# Papua New Guinea            64.50                 0.544000         5.051238
#
#                   Kmeans_clusters
# location
# Netherlands                     0
# Kuwait                          1
# Algeria                         1
# Lithuania                       0
# Monaco                          1
# Slovenia                        0
# Mozambique                      2
# Vatican                         1
# Paraguay                        1
# Chad                            2
# Austria                         0
# Namibia                         3
# Sweden                          0
# Laos                            3
# Papua New Guinea                3

# %%
cnt_new1[cnt_new1['Kmeans_clusters'] == 2].tail(20)
# Out:
#               median_age  aged_65_older  gdp_per_capita  extreme_poverty  \
# location
# Lesotho             22.2          4.506     2851.153000        59.600000
# Liberia             19.2          3.057      752.788000        38.600000
# Madagascar          19.6          2.929     1416.440000        77.600000
# Malawi              18.1          2.979     1095.042000        71.400000
# Mali                16.4          2.519     2014.306000        42.817857
# Mozambique          17.7          3.158     1136.103000        62.900000
# Niger               15.1          2.553      926.000000        44.500000
# Nigeria             18.1          2.751     5338.454000        42.817857
# Rwanda              20.3          2.974     1854.211000        56.000000
# Senegal             18.7          3.008     2470.580000        38.000000
# Sierra Leone        19.1          2.538     1390.300000        52.200000
# South Sudan         19.2          3.441     1569.888000        42.817857
# Sudan               19.7          3.548     4466.507000        42.817857
# Syria               21.7          8.696     1922.955886        42.817857
# Tanzania            17.7          3.108     2683.304000        49.100000
# Togo                19.4          2.839     1429.813000        49.200000
# Uganda              16.4          2.168     1697.707000        41.600000
# Yemen               20.3          2.922     1479.147000        18.800000
# Zambia              17.7          2.480     3689.251000        57.500000
# Zimbabwe            19.6          2.822     1899.775000        21.400000
#
#               life_expectancy  human_development_index  happiness_score  \
# location
# Lesotho                 54.33                    0.520         3.653000
# Liberia                 64.10                    0.435         4.558000
# Madagascar              67.04                    0.519         4.166000
# Malawi                  64.26                    0.477         3.538000
# Mali                    59.31                    0.427         4.729000
# Mozambique              60.85                    0.437         4.624000
# Niger                   62.42                    0.354         4.910000
# Nigeria                 54.69                    0.532         4.724000
# Rwanda                  69.02                    0.524         3.312000
# Senegal                 67.94                    0.505         4.981000
# Sierra Leone            54.70                    0.419         3.926000
# South Sudan             57.85                    0.388         2.817000
# Sudan                   65.31                    0.502         4.151667
# Syria                   72.70                    0.536         4.151667
# Tanzania                65.46                    0.538         3.476000
# Togo                    61.04                    0.503         4.187000
# Uganda                  63.37                    0.516         4.432000
# Yemen                   66.12                    0.452         3.527000
# Zambia                  63.89                    0.588         3.759000
# Zimbabwe                61.49                    0.535         3.299000
#
#               Kmeans_clusters
# location
# Lesotho                     2
# Liberia                     2
# Madagascar                  2
# Malawi                      2
# Mali                        2
# Mozambique                  2
# Niger                       2
# Nigeria                     2
# Rwanda                      2
# Senegal                     2
# Sierra Leone                2
# South Sudan                 2
# Sudan                       2
# Syria                       2
# Tanzania                    2
# Togo                        2
# Uganda                      2
# Yemen                       2
# Zambia                      2
# Zimbabwe                    2

# %%
cnt_new1[cnt_new1['Kmeans_clusters'] == 0].tail(20)
# Out:
#                       median_age  aged_65_older  gdp_per_capita  \
# location
# Lithuania                   43.5         19.002       29524.265
# Luxembourg                  39.7         14.312       94277.965
# Malta                       42.4         19.426       36513.323
# Netherlands                 43.2         18.779       48472.545
# New Zealand                 37.9         15.322       36085.843
# Norway                      39.7         16.821       64800.057
# Poland                      41.8         16.763       27216.445
# Portugal                    46.2         21.502       27936.896
# Qatar                       31.9          1.307      116935.600
# Romania                     43.0         17.850       23313.199
# Singapore                   42.4         12.922       85535.383
# Slovakia                    41.2         15.070       30155.152
# Slovenia                    44.5         19.062       31400.840
# South Korea                 43.4         13.914       35938.374
# Spain                       45.5         19.436       34272.360
# Sweden                      41.0         19.985       46949.283
# Switzerland                 43.1         18.436       57410.166
# United Arab Emirates        34.0          1.144       67293.483
# United Kingdom              40.8         18.517       39753.244
# United States               38.3         15.413       54225.446
#
#                       extreme_poverty  life_expectancy  \
# location
# Lithuania                    0.700000            75.93
# Luxembourg                   0.200000            82.25
# Malta                        0.200000            82.53
# Netherlands                  0.607407            82.28
# New Zealand                  0.607407            82.29
# Norway                       0.200000            82.40
# Poland                       0.607407            78.73
# Portugal                     0.500000            82.05
# Qatar                        0.607407            80.23
# Romania                      5.700000            76.05
# Singapore                    0.607407            83.62
# Slovakia                     0.700000            77.54
# Slovenia                     0.607407            81.32
# South Korea                  0.200000            83.03
# Spain                        1.000000            83.56
# Sweden                       0.500000            82.80
# Switzerland                  0.607407            83.78
# United Arab Emirates         0.607407            77.97
# United Kingdom               0.200000            81.32
# United States                1.200000            78.86
#
#                       human_development_index  happiness_score  \
# location
# Lithuania                               0.858         6.215000
# Luxembourg                              0.904         7.238000
# Malta                                   0.878         6.773000
# Netherlands                             0.931         7.449000
# New Zealand                             0.917         7.300000
# Norway                                  0.953         7.488000
# Poland                                  0.865         6.186000
# Portugal                                0.847         5.911000
# Qatar                                   0.856         6.659643
# Romania                                 0.811         6.124000
# Singapore                               0.932         6.377000
# Slovakia                                0.855         6.281000
# Slovenia                                0.896         6.363000
# South Korea                             0.903         5.872000
# Spain                                   0.891         6.401000
# Sweden                                  0.933         7.353000
# Switzerland                             0.944         7.560000
# United Arab Emirates                    0.863         6.791000
# United Kingdom                          0.922         7.165000
# United States                           0.924         6.940000
#
#                       Kmeans_clusters
# location
# Lithuania                           0
# Luxembourg                          0
# Malta                               0
# Netherlands                         0
# New Zealand                         0
# Norway                              0
# Poland                              0
# Portugal                            0
# Qatar                               0
# Romania                             0
# Singapore                           0
# Slovakia                            0
# Slovenia                            0
# South Korea                         0
# Spain                               0
# Sweden                              0
# Switzerland                         0
# United Arab Emirates                0
# United Kingdom                      0
# United States                       0

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
linked = linkage(cnt_new1_scaled, "ward")

# %%
plt.figure(figsize = (20,8))
plt.title("Dendogram")
plt.xlabel("Observations")
plt.ylabel("Distances")
dendrogram(linked);

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
Hr_model = AgglomerativeClustering (n_clusters = 4)
cnt_new1_scaled_pred_hr = Hr_model.fit_predict(cnt_new1_scaled)

# %%
clusters = Hr_model.labels_

# %%
np.unique(cnt_new1_scaled_pred_hr, return_counts=True)
# Out:
# (array([0, 1, 2, 3], dtype=int64), array([49, 36, 74, 31], dtype=int64))

# %%
silhouette_score(cnt_new1_scaled, cnt_new1_scaled_pred_hr)
# Out:
# 0.31211409747498703

# %%
cnt_new1["Hr_predicted_clusters"]=clusters

# %%
cnt_new1.sample(20)
# Out:
#                   median_age  aged_65_older  gdp_per_capita  extreme_poverty  \
# location
# Ghana                   21.1          3.385        4227.630        12.000000
# Bolivia                 25.4          6.704        6885.829         7.100000
# Marshall Islands        30.9          8.696        3819.202         2.355556
# Sweden                  41.0         19.985       46949.283         0.500000
# Italy                   47.9         23.021       35220.084         2.000000
# Canada                  41.4         16.984       44017.591         0.500000
# Ukraine                 41.4         16.462        7894.393         0.100000
# Portugal                46.2         21.502       27936.896         0.500000
# Argentina               31.9         11.198       18933.907         0.600000
# Guatemala               22.9          4.694        7423.808         8.700000
# Papua New Guinea        22.6          3.808        3823.194        16.845833
# Saint Lucia             34.9          9.721       12951.839         2.355556
# Belgium                 41.8         18.571       42658.576         0.200000
# Suriname                29.6          6.933       13767.119         2.355556
# Norway                  39.7         16.821       64800.057         0.200000
# Estonia                 42.7         19.452       29481.252         0.500000
# Costa Rica              33.6          9.468       15524.995         1.300000
# Kosovo                  30.9          8.696        9795.834         0.600000
# Philippines             25.2          4.803        7599.188         2.355556
# Chad                    16.7          2.486        1768.153        38.400000
#
#                   life_expectancy  human_development_index  happiness_score  \
# location
# Ghana                       64.07                 0.592000         5.148000
# Bolivia                     71.51                 0.693000         5.747000
# Marshall Islands            73.70                 0.708000         5.446964
# Sweden                      82.80                 0.933000         7.353000
# Italy                       83.51                 0.880000         6.387000
# Canada                      82.43                 0.926000         7.232000
# Ukraine                     72.06                 0.751000         4.561000
# Portugal                    82.05                 0.847000         5.911000
# Argentina                   76.67                 0.825000         5.975000
# Guatemala                   74.30                 0.650000         6.399000
# Papua New Guinea            64.50                 0.544000         5.051238
# Saint Lucia                 76.20                 0.747000         5.446964
# Belgium                     81.63                 0.916000         6.864000
# Suriname                    71.68                 0.720000         5.446964
# Norway                      82.40                 0.953000         7.488000
# Estonia                     78.74                 0.871000         6.022000
# Costa Rica                  80.28                 0.794000         7.121000
# Kosovo                      72.58                 0.708869         6.325000
# Philippines                 71.23                 0.699000         6.006000
# Chad                        54.24                 0.404000         4.423000
#
#                   Kmeans_clusters  Hr_predicted_clusters
# location
# Ghana                           3                      3
# Bolivia                         3                      2
# Marshall Islands                1                      2
# Sweden                          0                      0
# Italy                           0                      0
# Canada                          0                      0
# Ukraine                         1                      2
# Portugal                        0                      0
# Argentina                       1                      2
# Guatemala                       3                      2
# Papua New Guinea                3                      3
# Saint Lucia                     1                      2
# Belgium                         0                      0
# Suriname                        1                      2
# Norway                          0                      0
# Estonia                         0                      0
# Costa Rica                      1                      2
# Kosovo                          1                      2
# Philippines                     3                      2
# Chad                            2                      1

# %%
cnt_new1[cnt_new1['Kmeans_clusters'] == 0].index
# Out:
# Index(['Andorra', 'Australia', 'Austria', 'Belgium', 'Brunei', 'Bulgaria',
#        'Canada', 'Croatia', 'Czechia', 'Denmark', 'Estonia', 'Finland',
#        'France', 'Germany', 'Greece', 'Hong Kong', 'Hungary', 'Iceland',
#        'Ireland', 'Israel', 'Italy', 'Japan', 'Latvia', 'Liechtenstein',
#        'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 'New Zealand',
#        'Norway', 'Poland', 'Portugal', 'Qatar', 'Romania', 'Singapore',
#        'Slovakia', 'Slovenia', 'South Korea', 'Spain', 'Sweden', 'Switzerland',
#        'United Arab Emirates', 'United Kingdom', 'United States'],
#       dtype='object', name='location')

# %%
cnt_new1[cnt_new1['Hr_predicted_clusters'] == 2].index
# Out:
# Index(['Albania', 'Algeria', 'Antigua and Barbuda', 'Argentina', 'Armenia',
#        'Azerbaijan', 'Bahamas', 'Barbados', 'Belarus', 'Belize', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Brazil', 'Chile', 'China',
#        'Colombia', 'Costa Rica', 'Cuba', 'Dominica', 'Dominican Republic',
#        'Ecuador', 'El Salvador', 'Fiji', 'Georgia', 'Grenada', 'Guatemala',
#        'Honduras', 'Indonesia', 'Iran', 'Jamaica', 'Kazakhstan', 'Kosovo',
#        'Kyrgyzstan', 'Lebanon', 'Libya', 'Malaysia', 'Maldives',
#        'Marshall Islands', 'Mauritius', 'Mexico', 'Moldova', 'Monaco',
#        'Mongolia', 'Montenegro', 'Morocco', 'Nicaragua', 'North Macedonia',
#        'Panama', 'Paraguay', 'Peru', 'Philippines', 'Russia',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa', 'Serbia', 'Seychelles',
#        'Sri Lanka', 'Suriname', 'Taiwan', 'Tajikistan', 'Thailand',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Ukraine', 'Uruguay',
#        'Uzbekistan', 'Vatican', 'Venezuela', 'Vietnam', 'World'],
#       dtype='object', name='location')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(15,8))
ax1.set_title('Kmeans')
ax1.scatter(cnt_new1.iloc[:,0], cnt_new1.iloc[:,2], c = cnt_new1["Kmeans_clusters"], s = 50, cmap = "rainbow")
ax2.set_title("Hierarchical")
ax2.scatter(cnt_new1.iloc[:,0], cnt_new1.iloc[:,2], c = cnt_new1["Hr_predicted_clusters"], s = 50, cmap = "rainbow")

# %%
cnt_new1.to_csv("cnt.csv")
